# %% [markdown]
# # Ген. алгоритм "Распределение задач"
#
# ### Суть задачи: распределить задачи (1000) между программистами (10) так, чтобы максимальное время выполнения всех задач стремилось к минимуму

# %%
import numpy as np

# %%
def mutation(child, task_count, rng, p_mutat):
    chance = rng.random()
    if chance <=p_mutat:
        mutation_num = rng.integers(1, 4)
        #* Мутация обменом генов
        if mutation_num == 1:
            for _ in range(rng.integers(0, task_count)):
                fchromosome, schromosome = rng.integers(0, task_count), rng.integers(0, task_count)
                child[fchromosome], child[schromosome] = child[schromosome], child[fchromosome]
            return child
        #* Мутация обращением
        elif mutation_num == 2:
            fslice = rng.integers(0, task_count)
            sslice = rng.integers(fslice, task_count)
            child[fslice:sslice] = child[fslice:sslice][::-1]
            return child
        #* Мутация перетасовкой
        elif mutation_num == 3:
            fslice = rng.integers(0, task_count)
            sslice = rng.integers(fslice, task_count)
            np.random.shuffle(child[fslice:sslice])
            return child
    return child

# %%
def crossover(fparent, sparent, task_count, rng, p_cross):
    chance = round(rng.random(), 5)
    if chance <= p_cross:
        crossover_num = rng.integers(1, 4)
        #* Одноточечый кроссовер (скрещивание с одним срезом)
        if crossover_num == 1:
            gen_slice = rng.integers(0, task_count)
            fchild = np.concatenate([fparent[:gen_slice], sparent[gen_slice:]])
            schild = np.concatenate([sparent[:gen_slice], fparent[gen_slice:]])
            return fchild, schild
        #* Двухточечный кроссовер (скрещивание с двумя срезами)
        elif crossover_num == 2:
            fslice = rng.integers(0, task_count)
            sslice = rng.integers(fslice, task_count)
            fchild = np.concatenate([fparent[:fslice], sparent[fslice:sslice], fparent[sslice:]])
            schild = np.concatenate([sparent[:fslice], fparent[fslice:sslice], sparent[sslice:]])
            return fchild, schild
        #* Равномерное скрещивание
        elif crossover_num == 3:
            return [[rng.choice([fparent[gen], sparent[gen]]) for gen in range(task_count)] for _ in range(2)]
    return fparent, sparent

# %% [markdown]
# Данный блок selection работает хуже, так как лучшие особи могут пропускаться, из-за чего алгоритм отбора в последующих генерациях будет выдавать хучшие результаты и программе придется искать новые индивиды

# %%
# def selection(population, fitness_res, rng):
#     selection_num = rng.integers(1,4)
#     #* Стандартная выборка лучших особей в случайном срезе
#     if selection_num == 1:
#         return [ind for ind, _ in sorted(zip(population, fitness_res), key=lambda x: x[1])][:rng.choice([14, 22, 36, 42, 54])]
#     #* Случайная выборка особей в случайном диапазоне
#     elif selection_num == 2:
#         return [rng.choice(population, replace=False) for _ in range(rng.choice([14, 22, 36, 42, 54]))]
#     #* Выборка особей в перемешанном варианте в случайном диапазоне
#     elif selection_num == 3:
#         np.random.shuffle(population)
#         fslice, sslice = rng.choice([[14,36], [148, 192], [246, 304], [574, 620], [812, 888]])
#         return population[fslice:sslice]

# %%
def selection(population, fitness_res, rng):
    return [ind for ind, _ in sorted(zip(population, fitness_res), key=lambda x: x[1])][:rng.choice([14, 22, 36, 42, 54])]

# %%
def fitness(lvl_time, developer_count, developer_skills, individ):
    total_time = np.zeros(developer_count)
    
    for idx, ind in enumerate(individ):
        total_time[ind] += developer_skills[ind][int(lvl_time[idx][0])-1]*lvl_time[idx][1]
    return total_time.max()         #* Время окончания работы над проектом

# %%
def genetic_algoritm(task_count, lvl_time, developer_count, developer_skills, population_size, generation_size, p_cross, p_mutat):
    rng = np.random.default_rng()
    population = rng.integers(0, developer_count, size=(population_size, task_count))
    
    for gen in range(generation_size):
        fitness_res = np.array([fitness(lvl_time, developer_count, developer_skills, individ) for individ in population])
        print(f'Поколение {gen}: Приспособленность - {fitness_res.min()}')

        parents = selection(population, fitness_res, rng)
        childrens = []
        for _ in range(0, population_size-len(parents), 2):
            fparent, sparent = rng.choice(parents, size=2, replace=False)
            fchild, schild = crossover(fparent, sparent, task_count, rng, p_cross)
            fmutated_child = mutation(fchild, task_count, rng, p_mutat)
            smutated_child = mutation(schild, task_count, rng, p_mutat)
            childrens.extend([fmutated_child, smutated_child])
        population = parents + childrens
    
    return population[fitness_res.argmin()]

# %%
file = [rows.split() for rows in open('input.txt', 'r').readlines()]
task_count = int(*file[0])
lvl_time = np.array([np.array([int(lvl), float(time)]) for lvl, time in zip(file[1], file[2])])
developer_count = int(*file[3])
developer_skills = np.array([np.array(dev, dtype='float64') for dev in file[4:]])

# %%
population_size = 1000          #* Количество хромосом (элементов) в популяции
generation_size = 300          #* Количество генераций (поколений / итераций)

p_cross = 0.775                 #* Шанс кроссовера (скрещивания)
p_mutat = 0.225                 #* Шанс мутации (изменения гена)

# %%
solution = genetic_algoritm(task_count, lvl_time, developer_count, developer_skills, population_size, generation_size, p_cross, p_mutat)
output = open('output.txt', 'w').write(' '.join(map(str, solution)))
# Out:
# Поколение 0: Приспособленность - 681.3050000000003
# Поколение 1: Приспособленность - 659.7400000000002
# Поколение 2: Приспособленность - 638.0700000000003
# Поколение 3: Приспособленность - 637.3000000000002
# Поколение 4: Приспособленность - 633.2200000000001
# Поколение 5: Приспособленность - 625.6000000000003
# Поколение 6: Приспособленность - 625.5400000000001
# Поколение 7: Приспособленность - 623.05
# Поколение 8: Приспособленность - 618.0999999999999
# Поколение 9: Приспособленность - 616.9999999999997
# Поколение 10: Приспособленность - 615.7599999999996
# Поколение 11: Приспособленность - 615.5550000000002
# Поколение 12: Приспособленность - 615.5550000000002
# Поколение 13: Приспособленность - 615.5550000000002
# Поколение 14: Приспособленность - 615.5550000000002
# Поколение 15: Приспособленность - 615.47
# Поколение 16: Приспособленность - 615.3049999999997
# Поколение 17: Приспособленность - 615.0399999999998
# Поколение 18: Приспособленность - 614.0549999999998
# Поколение 19: Приспособленность - 614.0549999999998
# Поколение 20: Приспособленность - 614.0549999999998
# Поколение 21: Приспособленность - 614.0549999999998
# Поколение 22: Приспособленность - 614.0549999999998
# Поколение 23: Приспособленность - 614.0549999999998
# Поколение 24: Приспособленность - 614.0549999999998
# Поколение 25: Приспособленность - 614.0549999999998
# Поколение 26: Приспособленность - 613.8199999999998
# Поколение 27: Приспособленность - 613.8199999999998
# Поколение 28: Приспособленность - 613.0699999999997
# Поколение 29: Приспособленность - 613.0699999999997
# Поколение 30: Приспособленность - 613.0699999999997
# Поколение 31: Приспособленность - 613.0699999999997
# Поколение 32: Приспособленность - 613.0699999999997
# Поколение 33: Приспособленность - 612.4649999999998
# Поколение 34: Приспособленность - 612.4649999999998
# Поколение 35: Приспособленность - 612.4649999999998
# Поколение 36: Приспособленность - 612.4649999999998
# Поколение 37: Приспособленность - 612.4649999999998
# Поколение 38: Приспособленность - 612.4649999999998
# Поколение 39: Приспособленность - 610.6399999999998
# Поколение 40: Приспособленность - 610.6399999999998
# Поколение 41: Приспособленность - 610.6399999999998
# Поколение 42: Приспособленность - 610.6399999999998
# Поколение 43: Приспособленность - 610.6399999999998
# Поколение 44: Приспособленность - 610.4649999999998
# Поколение 45: Приспособленность - 609.9699999999997
# Поколение 46: Приспособленность - 609.9699999999997
# Поколение 47: Приспособленность - 609.9699999999997
# Поколение 48: Приспособленность - 609.9699999999997
# Поколение 49: Приспособленность - 609.9699999999997
# Поколение 50: Приспособленность - 609.9699999999997
# Поколение 51: Приспособленность - 609.9699999999997
# Поколение 52: Приспособленность - 609.9699999999997
# Поколение 53: Приспособленность - 609.9699999999997
# Поколение 54: Приспособленность - 609.9699999999997
# Поколение 55: Приспособленность - 609.9699999999997
# Поколение 56: Приспособленность - 609.9699999999997
# Поколение 57: Приспособленность - 609.9699999999997
# Поколение 58: Приспособленность - 609.9699999999997
# Поколение 59: Приспособленность - 609.6399999999998
# Поколение 60: Приспособленность - 609.6399999999998
# Поколение 61: Приспособленность - 609.1349999999999
# Поколение 62: Приспособленность - 609.1349999999999
# Поколение 63: Приспособленность - 609.1349999999999
# Поколение 64: Приспособленность - 609.1349999999999
# Поколение 65: Приспособленность - 609.1349999999999
# Поколение 66: Приспособленность - 609.1349999999999
# Поколение 67: Приспособленность - 609.1349999999999
# Поколение 68: Приспособленность - 609.1349999999999
# Поколение 69: Приспособленность - 608.53
# Поколение 70: Приспособленность - 608.53
# Поколение 71: Приспособленность - 608.53
# Поколение 72: Приспособленность - 608.53
# Поколение 73: Приспособленность - 608.53
# Поколение 74: Приспособленность - 608.53
# Поколение 75: Приспособленность - 608.53
# Поколение 76: Приспособленность - 608.53
# Поколение 77: Приспособленность - 608.53
# Поколение 78: Приспособленность - 608.53
# Поколение 79: Приспособленность - 608.53
# Поколение 80: Приспособленность - 608.53
# Поколение 81: Приспособленность - 608.2299999999998
# Поколение 82: Приспособленность - 608.2299999999998
# Поколение 83: Приспособленность - 608.2299999999998
# Поколение 84: Приспособленность - 608.2299999999998
# Поколение 85: Приспособленность - 608.2299999999998
# Поколение 86: Приспособленность - 608.2299999999998
# Поколение 87: Приспособленность - 608.2299999999998
# Поколение 88: Приспособленность - 608.2299999999998
# Поколение 89: Приспособленность - 608.2299999999998
# Поколение 90: Приспособленность - 608.2299999999998
# Поколение 91: Приспособленность - 608.2299999999998
# Поколение 92: Приспособленность - 608.2299999999998
# Поколение 93: Приспособленность - 608.2299999999998
# Поколение 94: Приспособленность - 608.2299999999998
# Поколение 95: Приспособленность - 608.2299999999998
# Поколение 96: Приспособленность - 608.2299999999998
# Поколение 97: Приспособленность - 608.2299999999998
# Поколение 98: Приспособленность - 608.2299999999998
# Поколение 99: Приспособленность - 608.2299999999998
# Поколение 100: Приспособленность - 608.2299999999998
# Поколение 101: Приспособленность - 608.2299999999998
# Поколение 102: Приспособленность - 608.2299999999998
# Поколение 103: Приспособленность - 608.2299999999998
# Поколение 104: Приспособленность - 608.2299999999998
# Поколение 105: Приспособленность - 608.1099999999997
# Поколение 106: Приспособленность - 608.1099999999997
# Поколение 107: Приспособленность - 608.1099999999997
# Поколение 108: Приспособленность - 608.1099999999997
# Поколение 109: Приспособленность - 608.1099999999997
# Поколение 110: Приспособленность - 608.1099999999997
# Поколение 111: Приспособленность - 608.1099999999997
# Поколение 112: Приспособленность - 608.1099999999997
# Поколение 113: Приспособленность - 607.5249999999997
# Поколение 114: Приспособленность - 607.5249999999997
# Поколение 115: Приспособленность - 607.5249999999997
# Поколение 116: Приспособленность - 607.5249999999997
# Поколение 117: Приспособленность - 607.5249999999997
# Поколение 118: Приспособленность - 607.5249999999997
# Поколение 119: Приспособленность - 607.5249999999997
# Поколение 120: Приспособленность - 607.5249999999997
# Поколение 121: Приспособленность - 607.5249999999997
# Поколение 122: Приспособленность - 607.5249999999997
# Поколение 123: Приспособленность - 607.5249999999997
# Поколение 124: Приспособленность - 607.5249999999997
# Поколение 125: Приспособленность - 607.5249999999997
# Поколение 126: Приспособленность - 607.5249999999997
# Поколение 127: Приспособленность - 607.5249999999997
# Поколение 128: Приспособленность - 607.5249999999997
# Поколение 129: Приспособленность - 607.5249999999997
# Поколение 130: Приспособленность - 607.5249999999997
# Поколение 131: Приспособленность - 607.5249999999997
# Поколение 132: Приспособленность - 607.5050000000001
# Поколение 133: Приспособленность - 607.5050000000001
# Поколение 134: Приспособленность - 607.2349999999998
# Поколение 135: Приспособленность - 607.2349999999998
# Поколение 136: Приспособленность - 607.2349999999998
# Поколение 137: Приспособленность - 607.2349999999998
# Поколение 138: Приспособленность - 607.2349999999998
# Поколение 139: Приспособленность - 607.2349999999998
# Поколение 140: Приспособленность - 607.2349999999998
# Поколение 141: Приспособленность - 607.2349999999998
# Поколение 142: Приспособленность - 607.2349999999998
# Поколение 143: Приспособленность - 607.2349999999998
# Поколение 144: Приспособленность - 607.2349999999998
# Поколение 145: Приспособленность - 607.2349999999998
# Поколение 146: Приспособленность - 607.2349999999998
# Поколение 147: Приспособленность - 607.2349999999998
# Поколение 148: Приспособленность - 607.2349999999998
# Поколение 149: Приспособленность - 607.2349999999998
# Поколение 150: Приспособленность - 607.2349999999998
# Поколение 151: Приспособленность - 607.2349999999998
# Поколение 152: Приспособленность - 607.2349999999998
# Поколение 153: Приспособленность - 607.2349999999998
# Поколение 154: Приспособленность - 607.2349999999998
# Поколение 155: Приспособленность - 607.2349999999998
# Поколение 156: Приспособленность - 607.2349999999998
# Поколение 157: Приспособленность - 607.2349999999998
# Поколение 158: Приспособленность - 607.2349999999998
# Поколение 159: Приспособленность - 607.2349999999998
# Поколение 160: Приспособленность - 607.2349999999998
# Поколение 161: Приспособленность - 607.12
# Поколение 162: Приспособленность - 607.12
# Поколение 163: Приспособленность - 607.12
# Поколение 164: Приспособленность - 607.12
# Поколение 165: Приспособленность - 607.12
# Поколение 166: Приспособленность - 607.12
# Поколение 167: Приспособленность - 607.12
# Поколение 168: Приспособленность - 607.12
# Поколение 169: Приспособленность - 607.12
# Поколение 170: Приспособленность - 607.12
# Поколение 171: Приспособленность - 607.12
# Поколение 172: Приспособленность - 607.12
# Поколение 173: Приспособленность - 607.12
# Поколение 174: Приспособленность - 607.12
# Поколение 175: Приспособленность - 607.12
# Поколение 176: Приспособленность - 607.12
# Поколение 177: Приспособленность - 607.0149999999998
# Поколение 178: Приспособленность - 607.0149999999998
# Поколение 179: Приспособленность - 607.0149999999998
# Поколение 180: Приспособленность - 607.0149999999998
# Поколение 181: Приспособленность - 607.0149999999998
# Поколение 182: Приспособленность - 607.0149999999998
# Поколение 183: Приспособленность - 607.0149999999998
# Поколение 184: Приспособленность - 607.0149999999998
# Поколение 185: Приспособленность - 607.0149999999998
# Поколение 186: Приспособленность - 607.0149999999998
# Поколение 187: Приспособленность - 607.0149999999998
# Поколение 188: Приспособленность - 607.0149999999998
# Поколение 189: Приспособленность - 607.0149999999998
# Поколение 190: Приспособленность - 607.0149999999998
# Поколение 191: Приспособленность - 607.0149999999998
# Поколение 192: Приспособленность - 607.0149999999998
# Поколение 193: Приспособленность - 607.0149999999998
# Поколение 194: Приспособленность - 607.0149999999998
# Поколение 195: Приспособленность - 607.0149999999998
# Поколение 196: Приспособленность - 607.0149999999998
# Поколение 197: Приспособленность - 607.0149999999998
# Поколение 198: Приспособленность - 607.0149999999998
# Поколение 199: Приспособленность - 607.0149999999998
# Поколение 200: Приспособленность - 607.0149999999998
# Поколение 201: Приспособленность - 607.0149999999998
# Поколение 202: Приспособленность - 607.0149999999998
# Поколение 203: Приспособленность - 607.0149999999998
# Поколение 204: Приспособленность - 607.0149999999998
# Поколение 205: Приспособленность - 607.0149999999998
# Поколение 206: Приспособленность - 607.0149999999998
# Поколение 207: Приспособленность - 607.0149999999998
# Поколение 208: Приспособленность - 607.0149999999998
# Поколение 209: Приспособленность - 607.0149999999998
# Поколение 210: Приспособленность - 607.0149999999998
# Поколение 211: Приспособленность - 607.0149999999998
# Поколение 212: Приспособленность - 607.0149999999998
# Поколение 213: Приспособленность - 607.0149999999998
# Поколение 214: Приспособленность - 607.0149999999998
# Поколение 215: Приспособленность - 607.0149999999998
# Поколение 216: Приспособленность - 607.0149999999998
# Поколение 217: Приспособленность - 607.0149999999998
# Поколение 218: Приспособленность - 607.0149999999998
# Поколение 219: Приспособленность - 607.0149999999998
# Поколение 220: Приспособленность - 607.0149999999998
# Поколение 221: Приспособленность - 607.0149999999998
# Поколение 222: Приспособленность - 607.0149999999998
# Поколение 223: Приспособленность - 607.0149999999998
# Поколение 224: Приспособленность - 607.0149999999998
# Поколение 225: Приспособленность - 607.0149999999998
# Поколение 226: Приспособленность - 607.0149999999998
# Поколение 227: Приспособленность - 607.0149999999998
# Поколение 228: Приспособленность - 607.0149999999998
# Поколение 229: Приспособленность - 607.0149999999998
# Поколение 230: Приспособленность - 607.0149999999998
# Поколение 231: Приспособленность - 607.0149999999998
# Поколение 232: Приспособленность - 607.0149999999998
# Поколение 233: Приспособленность - 607.0149999999998
# Поколение 234: Приспособленность - 607.0149999999998
# Поколение 235: Приспособленность - 607.0149999999998
# Поколение 236: Приспособленность - 607.0149999999998
# Поколение 237: Приспособленность - 607.0149999999998
# Поколение 238: Приспособленность - 607.0149999999998
# Поколение 239: Приспособленность - 607.0149999999998
# Поколение 240: Приспособленность - 607.0149999999998
# Поколение 241: Приспособленность - 607.0149999999998
# Поколение 242: Приспособленность - 607.0149999999998
# Поколение 243: Приспособленность - 607.0149999999998
# Поколение 244: Приспособленность - 607.0149999999998
# Поколение 245: Приспособленность - 607.0149999999998
# Поколение 246: Приспособленность - 607.0149999999998
# Поколение 247: Приспособленность - 607.0149999999998
# Поколение 248: Приспособленность - 607.0149999999998
# Поколение 249: Приспособленность - 607.0149999999998
# Поколение 250: Приспособленность - 607.0149999999998
# Поколение 251: Приспособленность - 607.0149999999998
# Поколение 252: Приспособленность - 607.0149999999998
# Поколение 253: Приспособленность - 607.0149999999998
# Поколение 254: Приспособленность - 607.0149999999998
# Поколение 255: Приспособленность - 607.0149999999998
# Поколение 256: Приспособленность - 607.0149999999998
# Поколение 257: Приспособленность - 607.0149999999998
# Поколение 258: Приспособленность - 607.0149999999998
# Поколение 259: Приспособленность - 607.0149999999998
# Поколение 260: Приспособленность - 607.0149999999998
# Поколение 261: Приспособленность - 607.0149999999998
# Поколение 262: Приспособленность - 607.0149999999998
# Поколение 263: Приспособленность - 607.0049999999999
# Поколение 264: Приспособленность - 607.0049999999999
# Поколение 265: Приспособленность - 607.0049999999999
# Поколение 266: Приспособленность - 607.0049999999999
# Поколение 267: Приспособленность - 607.0049999999999
# Поколение 268: Приспособленность - 607.0049999999999
# Поколение 269: Приспособленность - 607.0049999999999
# Поколение 270: Приспособленность - 607.0049999999999
# Поколение 271: Приспособленность - 607.0049999999999
# Поколение 272: Приспособленность - 607.0049999999999
# Поколение 273: Приспособленность - 607.0049999999999
# Поколение 274: Приспособленность - 607.0049999999999
# Поколение 275: Приспособленность - 607.0049999999999
# Поколение 276: Приспособленность - 607.0049999999999
# Поколение 277: Приспособленность - 607.0049999999999
# Поколение 278: Приспособленность - 607.0049999999999
# Поколение 279: Приспособленность - 607.0049999999999
# Поколение 280: Приспособленность - 607.0049999999999
# Поколение 281: Приспособленность - 607.0049999999999
# Поколение 282: Приспособленность - 607.0049999999999
# Поколение 283: Приспособленность - 607.0049999999999
# Поколение 284: Приспособленность - 606.7099999999999
# Поколение 285: Приспособленность - 606.7099999999999
# Поколение 286: Приспособленность - 606.7099999999999
# Поколение 287: Приспособленность - 606.7099999999999
# Поколение 288: Приспособленность - 606.7099999999999
# Поколение 289: Приспособленность - 606.7099999999999
# Поколение 290: Приспособленность - 606.7099999999999
# Поколение 291: Приспособленность - 606.7099999999999
# Поколение 292: Приспособленность - 606.7099999999999
# Поколение 293: Приспособленность - 606.7099999999999
# Поколение 294: Приспособленность - 606.7099999999999
# Поколение 295: Приспособленность - 606.7099999999999
# Поколение 296: Приспособленность - 606.58
# Поколение 297: Приспособленность - 606.58
# Поколение 298: Приспособленность - 606.58
# Поколение 299: Приспособленность - 606.58
